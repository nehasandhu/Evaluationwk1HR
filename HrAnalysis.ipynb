# %% [markdown]
# # Problem Discription :

# %% [markdown]
# HR Analytics
#
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.
#
# It’s important to recognize that there are actually two types of attrition problems: too little and too much.
#
# When considering attrition, many leaders tend to focus on the problem of high turnover – with good reason. Recruiting, hiring, onboarding, and training new employees costs businesses billions each year. Companies also suffer productivity losses – and lost profits – when there is a large amount of continuous churn in the workforce.
#
# The first step to building an employee retention model is to determine who is leaving the organization, when they are leaving, and why they are leaving.
#
# Because each organization has its own ideal balance between employee attrition and retention, an effective employee retention model will be unique to the organization and focus on its biggest challenges. And because different employees have different reasons for leaving, the organization needs to be creative and flexible in the actions it takes to retain hard-to-replace talent or extend the tenure of employees in transitional positions.

# %% [markdown]
# # Data Analysis

# %%
#importing pandas and numpy libraries
import pandas as pd
import numpy as np

# %%
#importing the data set to work on for Data Analysis

df = pd.read_excel (r'E:\DataTrained\hr.xlsx')
print (df)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# preprocessing the Dataset by dealing with the missing values in the Dataset
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
#                             0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# reading the number of columns from the data set baseball.
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', '  ', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Checking the datatypes
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
#                              int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# Observation - There are no Null values in th Data set .

# %% [markdown]
# # Analysis of Data using Visualization of all the features

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
fig, ax = plt.subplots(figsize=(25, 10))
ax = sns.countplot(x="Age", data=df, facecolor=(0, 0, 0, 0), linewidth=10, 
                  edgecolor=sns.color_palette("dark",24)).set_title("Age Distribution")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax = sns.countplot(x="Attrition", data=df, facecolor=(0, 0, 0, 0), linewidth=10, 
                  edgecolor=sns.color_palette("dark",24)).set_title("Attrition Distribution")
plt.xlabel("Attrition")
# Out:
# Text(0.5, 0, 'Attrition')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax = sns.countplot(x="BusinessTravel", data=df, facecolor=(0, 0, 0, 0), linewidth=10, 
                  edgecolor=sns.color_palette("dark",24)).set_title("BusinessTravel Distribution")
plt.xlabel("BusinessTravel")
# Out:
# Text(0.5, 0, 'BusinessTravel')

# %%
fig, ax = plt.subplots(figsize=(10, 3))
ax = sns.countplot(x="Department", data=df, facecolor=(0, 0, 0, 0), linewidth=10, 
                  edgecolor=sns.color_palette("dark",24)).set_title("Department Distribution")
plt.xlabel("Department")
# Out:
# Text(0.5, 0, 'Department')

# %%
fig, ax = plt.subplots(figsize=(25, 7))
ax = sns.countplot(x="DistanceFromHome", data=df, facecolor=(0, 0, 0, 0), linewidth=10, 
                  edgecolor=sns.color_palette("dark",24)).set_title("DistanceFromHome Distribution")
plt.xlabel("DistanceFromHome")
# Out:
# Text(0.5, 0, 'DistanceFromHome')

# %%
fig, ax = plt.subplots(figsize=(25, 7))
ax = sns.countplot(x="DistanceFromHome", data=df, facecolor=(0, 0, 0, 0), linewidth=10, 
                  edgecolor=sns.color_palette("dark",24)).set_title("DistanceFromHome Distribution")
plt.xlabel("DistanceFromHome")
# Out:
# Text(0.5, 0, 'DistanceFromHome')

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax = sns.countplot(x="EducationField", data=df, facecolor=(0, 0, 0, 0), linewidth=10, 
                  edgecolor=sns.color_palette("dark",24)).set_title("EducationField Distribution")
plt.xlabel("EducationField")
# Out:
# Text(0.5, 0, 'EducationField')

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax = sns.countplot(x="EnvironmentSatisfaction", data=df, facecolor=(0, 0, 0, 0), linewidth=10, 
                  edgecolor=sns.color_palette("dark",24)).set_title("EducationField Distribution")
plt.xlabel("EnvironmentSatisfaction")
# Out:
# Text(0.5, 0, 'EnvironmentSatisfaction')

# %%
fig, ax = plt.subplots(figsize=(10, 7))
ax = sns.countplot(x="YearsSinceLastPromotion", data=df, facecolor=(0, 0, 0, 0), linewidth=10, 
                  edgecolor=sns.color_palette("dark",24)).set_title("YearsSinceLastPromotion Distribution")
plt.xlabel("YearsSinceLastPromotion")
# Out:
# Text(0.5, 0, 'YearsSinceLastPromotion')

# %%
df.corr
# Out:
# <bound method DataFrame.corr of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
   df.describe(include="all")
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %% [markdown]
# Checking Null values

# %%
df['DailyRate'].unique()
# Out:
# array([1102,  279, 1373, 1392,  591, 1005, 1324, 1358,  216, 1299,  809,
#         153,  670, 1346,  103, 1389,  334, 1123, 1219,  371,  673, 1218,
#         419,  391,  699, 1282, 1125,  691,  477,  705,  924, 1459,  125,
#         895,  813, 1273,  869,  890,  852, 1141,  464, 1240, 1357,  994,
#         721, 1360, 1065,  408, 1211, 1229,  626, 1434, 1488, 1097, 1443,
#         515,  853, 1142,  655, 1115,  427,  653,  989, 1435, 1223,  836,
#        1195, 1339,  664,  318, 1225, 1328, 1082,  548,  132,  746,  776,
#         193,  397,  945, 1214,  111,  573, 1153, 1400,  541,  432,  288,
#         669,  530,  632, 1334,  638, 1093, 1217, 1353,  120,  682,  489,
#         807,  827,  871,  665, 1040, 1420,  240, 1280,  534, 1456,  658,
#         142, 1127, 1031, 1189, 1354, 1467,  922,  394, 1312,  750,  441,
#         684,  249,  841,  147,  528,  594,  470,  957,  542,  802, 1355,
#        1150, 1329,  959, 1033, 1316,  364,  438,  689,  201, 1427,  857,
# ...

# %%
#Getting the number of rows and number of columns in the data
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# Observation : There are 1470 rows and 35 columns in the dataset

# %% [markdown]
# #Counting the empty Nan values in each column

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
#                             0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Obsevation - There are non Nan values now we will find the missing values

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Obsevation - There are no missing values in the dataset

# %% [markdown]
# Describing the Dataset

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#Get a count of the number of employee attrition, the number of employees that stayed (no) and the number that left (yes)
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# Observation
# 1233 employes said No
# 237 employes said Yes

# %%
#Get of the object data types and their unique values

# %%
for column in df.columns:
    if df[column].dtype == object:
        print(str(column) + ' : ' + str(df[column].unique()))
        print(df[column].value_counts())
        print("*******************************************")
# Out:
# Attrition : ['Yes' 'No']
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# *******************************************
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# *******************************************
# Department : ['Sales' 'Research & Development' 'Human Resources']
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# *******************************************
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# *******************************************
# Gender : ['Female' 'Male']
# ...

# %% [markdown]
# Remove unwanted columns from the dataset

# %%
df = df.drop('EmployeeNumber', axis = 1) # A number assignment 
#Remove the column StandardHours
df = df.drop('StandardHours', axis = 1) #Contains only value 80 
#Remove the column EmployeeCount
df = df.drop('EmployeeCount', axis = 1) #Contains only the value 1 
#Remove the column EmployeeCount
df = df.drop('Over18', axis = 1) #Contains only the value 'Yes'

# %%
#Finding the correlation of dataset
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
#                           0.028051  -0.032182          0.027473  -0.026084
# ...

# %%
#Visualization using heatmap
plt.figure(figsize=(14,14))  #14in by 14in
sns.heatmap(df.corr(), annot=True, fmt='.0%')
# Out:
# <AxesSubplot:>

# %%
#converting the data column to the numeric column
from sklearn.preprocessing import LabelEncoder


for column in df.columns:
        if df[column].dtype == np.number:
            continue
        df[column] = LabelEncoder().fit_transform(df[column])
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_12160/1444204860.py:6: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df[column].dtype == np.number:

# %%
df['Age_Years'] = df['Age']

# %%
#droping the Age column
df = df.drop('Age', axis = 1)

# %%
df
# Out:
#       Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0             1               2        624           2                 0
# 1             0               1        113           1                 7
# 2             1               2        805           1                 1
# 3             0               1        820           1                 2
# 4             0               2        312           1                 1
# ...         ...             ...        ...         ...               ...
# 1465          0               1        494           1                22
# 1466          0               2        327           1                 5
# 1467          0               2         39           1                 3
# 1468          0               1        579           2                 1
# 1469          0               2        336           1                 7
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %% [markdown]
# Converting the Data into X and Y variable

# %%
X = df.iloc[:, 1:df.shape[1]].values 
Y = df.iloc[:, 0].values

# %%
#Spliting the data as  75% training and 25 % testing 
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

# %%
# Random forest classifier to test our Data model accuracy 
from sklearn.ensemble import RandomForestClassifier
  
forest = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
forest.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
#Get the accuracy on the training data
forest.score(X_train, Y_train)
# Out:
# 0.9791288566243194

# %% [markdown]
# Observation - This good accuracy for model

# %%
#algorithm to find the highest number of importance
importances = pd.DataFrame({'feature':df.iloc[:, 1:df.shape[1]].columns,'importance':np.round(forest.feature_importances_,3)}) #Note: The target column is at position 0
importances = importances.sort_values('importance',ascending=False).set_index('feature')
importances
# Out:
#                           importance
# feature
# MonthlyIncome                  0.071
# Age_Years                      0.067
# DailyRate                      0.067
#                                0.055
# HourlyRate                     0.052
# TotalWorkingYears              0.051
# YearsWithCurrManager           0.048
# JobRole                        0.044
# DistanceFromHome               0.042
# OverTime                       0.040
# YearsAtCompany                 0.038
# PercentSalaryHike              0.038
# RelationshipSatisfaction       0.035
# EnvironmentSatisfaction        0.032
# TrainingTimesLastYear          0.030
# NumCompaniesWorked             0.029
# YearsInCurrentRole             0.028
# MaritalStatus                  0.027
# JobLevel                       0.025
# JobSatisfaction                0.025
# JobInvolvement                 0.024
# EducationField                 0.024
# YearsSinceLastPromotion        0.022
# StockOptionLevel               0.020
# ...

# %%
importances.plot.bar()
# Out:
# <AxesSubplot:xlabel='feature'>

# %% [markdown]
# Conclution - Monthly income is the most important feature in the dataset we can also think of considering the Age feature which is also impotant feature.
